# %% [markdown]
# ## Supreme Data Hackathon Submission
# ### Problem Statement: Determine the Malaria High Risk countries
# ## Name: Adegbite Ayoade Abel
# ## Tool: Python with Jupyter Notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Import Dataset

# %%
cases= pd.read_csv('DatasetAfricaMalaria.csv')
cases.head()
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# ...

# %% [markdown]
# # EDA Process

# %%
cases.shape
# Out:
# (594, 27)

# %%
cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 27 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Country Name                                                                             594 non-null    object
#  1   Year                                                                                     594 non-null    int64
#  2   Country Code                                                                             594 non-null    object
#  3   Incidence of malaria (per 1,000 population at risk)                                      550 non-null    float64
#  4   Malaria cases reported                                                                   550 non-null    float64
# ...

# %% [markdown]
# ### Plotting the missing values to visual for easy identification

# %%
missing_vals = msno.bar(cases,color = "lightskyblue")
missing_vals

# %% [markdown]
# # Visualization for more insights

# %%
df_corr_mal = cases[['Malaria cases reported',
'People using safely managed drinking water services, rural (% of rural population)',
'People using safely managed drinking water services, urban (% of urban population)',
'People using safely managed sanitation services, rural (% of rural population)',
'People using at least basic drinking water services, urban (% of urban population)',
'People using at least basic drinking water services, rural (% of rural population)',
'People using at least basic drinking water services, urban (% of urban population)',
'People using at least basic sanitation services, rural (% of rural population)',
'People using at least basic sanitation services, urban  (% of urban population)'
]]

# visualize the correlation
plt.figure(figsize=(15,10))
sns.heatmap(df_corr_mal.iloc[:,0:15].corr(), annot=True,fmt=".0%")
plt.show()

# %%
df_corr_pop = cases[['Malaria cases reported','Rural population (% of total population)',
       'Rural population growth (annual %)',
       'Urban population (% of total population)',
       'Urban population growth (annual %)'
]]

# visualize the correlation
plt.figure(figsize=(15,10))
sns.heatmap(df_corr_pop.iloc[:,0:15].corr(), annot=True,fmt=".0%")
plt.show()

# %%
df_corr_treat = cases[['Malaria cases reported','Use of insecticide-treated bed nets (% of under-5 population)',
       'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
       'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)'
]]

# visualize the correlation
plt.figure(figsize=(15,10))
sns.heatmap(df_corr_treat.iloc[:,0:15].corr(), annot=True,fmt=".0%")
plt.show()

# %% [markdown]
# # Top 50 countries with largest number of cases in 2017

# %%
df1 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df1 = df1[df1['Year']==2017][:50]
plt.figure(figsize=(18,10))
sns.barplot(df1['Country Name'], df1['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df1[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 551  Congo, Dem. Rep.              16793002.0
# 591            Uganda              11667831.0
# 578           Nigeria              11639713.0
# 544      Burkina Faso              10255415.0
# 575        Mozambique               9892601.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2016

# %%
df2 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df2 = df2[df2['Year']==2016][:50]
plt.figure(figsize=(18,10))
sns.barplot(df2['Country Name'], df2['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df2[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 497  Congo, Dem. Rep.              16821130.0
# 524           Nigeria              12293820.0
# 490      Burkina Faso               9779411.0
# 521        Mozambique               9690873.0
# 537            Uganda               9385132.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2015

# %%
df3 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df3 = df3[df3['Year']==2015][:50]
plt.figure(figsize=(18,10))
sns.barplot(df3['Country Name'], df3['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df3[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 443  Congo, Dem. Rep.              12538805.0
# 467        Mozambique               8222814.0
# 483            Uganda               7137662.0
# 470           Nigeria               7131972.0
# 436      Burkina Faso               7015446.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2014

# %%
df4 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df4 = df4[df4['Year']==2014][:50]
plt.figure(figsize=(18,10))
sns.barplot(df4['Country Name'], df4['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df4[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 389  Congo, Dem. Rep.              10288519.0
# 416           Nigeria               7826954.0
# 413        Mozambique               7407175.0
# 382      Burkina Faso               5428655.0
# 383           Burundi               4726299.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2013

# %%
df5 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df5 = df5[df5['Year']==2013][:50]
plt.figure(figsize=(18,10))
sns.barplot(df5['Country Name'], df5['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df5[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 335  Congo, Dem. Rep.               6719887.0
# 329           Burundi               4178338.0
# 328      Burkina Faso               3769051.0
# 359        Mozambique               3282172.0
# 343          Ethiopia               2645454.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2012

# %%
df6 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df6 = df6[df6['Year']==2012][:50]
plt.figure(figsize=(18,10))
sns.barplot(df6['Country Name'], df6['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df6[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 281  Congo, Dem. Rep.               4791598.0
# 274      Burkina Faso               3858046.0
# 292             Ghana               3755166.0
# 321            Uganda               2662258.0
# 307             Niger               2329260.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2011

# %%
df7 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df7 = df7[df7['Year']==2011][:50]
plt.figure(figsize=(18,10))
sns.barplot(df7['Country Name'], df7['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df7[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 227  Congo, Dem. Rep.               4561981.0
# 264          Tanzania               2150761.0
# 243           Liberia               1921159.0
# 251        Mozambique               1756874.0
# 217            Angola               1632282.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2010

# %%
df8 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df8 = df8[df8['Year']==2010][:50]
plt.figure(figsize=(18,10))
sns.barplot(df8['Country Name'], df8['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df8[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 173  Congo, Dem. Rep.               2417780.0
# 167           Burundi               1763447.0
# 163            Angola               1682870.0
# 213            Uganda               1581160.0
# 197        Mozambique               1522577.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2009

# %%
df9 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df9 = df9[df9['Year']==2009][:50]
plt.figure(figsize=(18,10))
sns.barplot(df9['Country Name'], df9['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df9[['Country Name','Malaria cases reported']].head()
# Out:
#          Country Name  Malaria cases reported
# 119  Congo, Dem. Rep.               1879694.0
# 109            Angola               1573422.0
# 159            Uganda               1301337.0
# 113           Burundi               1185622.0
# 127          Ethiopia               1144640.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2008

# %%
df10 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df10 = df10[df10['Year']==2008][:50]
plt.figure(figsize=(18,10))
sns.barplot(df10['Country Name'], df10['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df10[['Country Name','Malaria cases reported']].head()
# Out:
#     Country Name  Malaria cases reported
# 55        Angola               1377992.0
# 76         Ghana               1094483.0
# 105       Uganda                979298.0
# 59       Burundi                876741.0
# 79         Kenya                839903.0

# %% [markdown]
# # Top 50 countries with largest number of cases in 2007

# %%
df11 = cases.sort_values(by = 'Malaria cases reported', ascending=False)
df11 = df11[df11['Year']==2007][:50]
plt.figure(figsize=(18,10))
sns.barplot(df11['Country Name'], df11['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');

# %%
df11[['Country Name','Malaria cases reported']].head()
# Out:
#         Country Name  Malaria cases reported
# 48          Tanzania               1845917.0
# 1             Angola               1533485.0
# 5            Burundi               1101644.0
# 51            Uganda               1045378.0
# 11  Congo, Dem. Rep.                740858.0

# %% [markdown]
# ### Relationship between number of Malaria cases reported and Incidence of malaria (per 1,000 population at risk)

# %%
plt.figure(figsize =(8,5))
plt.title('Relationship between number of Malaria cases reported and Incidence of malaria (per 1,000 population at risk)',
          fontsize=14, fontweight='bold')
ax =sns.scatterplot(x= 'Malaria cases reported', y ='Incidence of malaria (per 1,000 population at risk)'
                    ,data = cases)

# %%
num_per_year=cases.groupby('Year').sum()
#print(np.sort(num_per_year['Malaria cases reported']).tolist())
num_per_year['Malaria cases reported']
# Out:
# Year
# 2007     10102341.0
# 2008      9508374.0
# 2009     14414616.0
# 2010     22184760.0
# 2011     23002865.0
# 2012     39719221.0
# 2013     47174959.0
# 2014     77028814.0
# 2015     92968526.0
# 2016    123330818.0
# 2017    128146255.0
# Name: Malaria cases reported, dtype: float64

# %%
df_mal =cases.groupby('Year').sum().loc[:, ['Malaria cases reported']]
plt.figure(figsize =(8,5))
ax = sns.lineplot(data=df_mal,markers=True)
plt.xlabel('Year', fontsize=15)
plt.title('Malaria cases reported by year', fontsize=14, fontweight='bold',color='red' );
plt.show();

# %% [markdown]
# ### Malaria cases reported and Incidence of malaria (per 1,000 population at risk) per Country

# %%
df_mal_code =cases.groupby('Country Code').sum().loc[:, ['Malaria cases reported',
                                                         'Incidence of malaria (per 1,000 population at risk)']]

print(df_mal_code.head())


plt.figure(figsize =(30,7))
ax = sns.lineplot(data=df_mal_code,markers=True)
plt.xlabel('Year', fontsize=15)
plt.title('Malaria cases reported and Incidence of malaria (per 1,000 population at risk) in particular Country', 
          fontsize=20, fontweight='bold')
plt.show()
# Out:
#               Malaria cases reported  \
# Country Code
# AGO                       24034182.0
# BDI                       40249714.0
# BEN                        8579720.0
# BFA                       41601963.0
# BWA                           8756.0
#
#               Incidence of malaria (per 1,000 population at risk)
# Country Code
# AGO                                                     2285.93
# BDI                                                     2138.23
# BEN                                                     4514.47
# BFA                                                     5332.90
# BWA                                                       12.74

# %%
plt.figure(figsize=(14,7))

sns.barplot(x='Year', y='Malaria cases reported', data=cases)

# %% [markdown]
# # Malaria reported in each country in their Rural area

# %%
plt.figure(figsize=(25,7))
plt.title("Malaria reported in each country in their Rural area", fontsize=17, fontweight='bold')
sns.scatterplot(x='Country Code', y='Malaria cases reported', hue='Rural population (% of total population)', data=cases);

# %% [markdown]
# # Malaria reported in each country in their Urban area

# %%
plt.figure(figsize=(25,7))
plt.title("Malaria reported in each country in their Urban area", fontsize=17, fontweight='bold')
sns.scatterplot(x='Country Code', y='Malaria cases reported', hue='Urban population (% of total population)', data=cases);

# %% [markdown]
# # Recommendations

# %% [markdown]
# #### From 2007 road up to 2017.<br>
#
#
# ### 2007 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |-------------------|------------|
# |  Tanzania | 1845917.0 |
# |  Angola   | 1533485.0  |
# |  Burundi   | 1101644.0 |
# |  Uganda | 1045378.0 |
# | Congo, Dem. Rep.  | 740858.0  |
#
# ### 2008 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# | Angola  |  1377992.0 |
# |  Ghana | 1094483.0  |
# |  Uganda | 979298.0  |
# |  Burundi | 876741.0  |
# | Kenya    | 839903.0 |
#
#
# ### 2009 Top 5<br>
# | Country Name      | Malaria cases reported  |
# |---|---|
# | Congo, Dem. Rep.  | 1879694.0  |
# | Angola  |  1573422.0 |
# |  Uganda | 1301337.0  |
# |  Burundi | 1185622.0  |
# |	Ethiopia|1144640.0|
#
# ### 2010 Top 5<br>
# | Country Name      | Malaria cases reported  |
# |---|---|
# |  Congo, Dem. Rep. | 2417780.0  |
# |  Burundi	 | 1763447.0  |
# |  Angola | 1682870.0  |
# |  Uganda |  1581160.0 |
# |  Mozambique | 1522577.0  |
#
# ### 2011 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# |  Congo, Dem. Rep. | 4561981.0  |
# |  Tanzania |  2150761.0 |
# |  Liberia	 |1921159.0|
# |  Mozambique |  1756874.0 |
# |  Angola | 1632282.0  |
#
#
# ### 2012 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# |Congo, Dem. Rep.   | 4791598.0  |
# |  Burkina Faso | 3858046.0  |
# | Ghana  | 3755166.0  |
# |  Uganda |2662258.0   |
# |  Niger |2329260.0   |
#
# ### 2013 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# | Congo, Dem. Rep.  | 6719887.0  |
# | Burundi  | 4178338.0  |
# |  	Burkina Faso | 3769051.0  |
# |  Mozambique |  3282172.0 |
# |  Ethiopia |  2645454.0 |
#
# ### 2014 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# | Congo, Dem. Rep.  | 10288519.0  |
# |  Nigeria | 7826954.0  |
# |  Mozambique | 7407175.0  |
# |  Burkina Faso | 5428655.0  |
# |  Burundi | 4726299.0  |
#
# ### 2015 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# |   Congo, Dem. Rep.| 12538805.0  |
# |  Mozambique |8222814.0   |
# |  Uganda |  7137662.0 |
# |  Nigeria | 7131972.0  |
# | Burkina Faso  | 7015446.0  |
#
# ### 2016 Top 5<br>
#
# | Country Name      | Malaria cases reported  |
# |---|---|
# |  Congo, Dem. Rep. | 16821130.0  |
# |   Nigeria|12293820.0   |
# |  Burkina Faso | 9779411.0  |
# |  Mozambique | 9690873.0  |
# | Uganda  | 9385132.0  |
#
# ### 2017 Top 5<br>
# | Country Name      | Malaria cases reported  |
# |---|---|
# |Congo, Dem. Rep.|16793002.0|
# | Uganda  | 11667831.0  |
# | Nigeria  | 11639713.0  |
# | Burkina Faso  | 10255415.0   |
# | Mozambique  | 9892601.0  |
#
#
# we can see Congo, Dem. Rep. appears most among the top 5 countries with largest number of cases.<br>
#
# Tackling countries like *Nigeria which shoot up from 0 reported cases in 2007 to  2008(143079 cases),2009(479845 cases),2010(551187 cases) and no cases through 2010-2013 and came back to top 15 in 2014 and has maitained that position through to 2017.* <br>
#
# With this in mind, targeting countries like this will help combact the impact of Malaria in Africa
# #### Thank you

# %% [markdown]
# # Bonus (Indepth look into Nigeria)

# %%
nig = cases.sort_values(by = 'Malaria cases reported', ascending=False)
nig = nig[nig['Country Name']=='Nigeria'][:]
plt.figure(figsize=(18,10))
sns.barplot(nig['Year'], nig['Malaria cases reported'])
plt.xticks(rotation=90, ha='right');
